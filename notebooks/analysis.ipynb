# %%
import sys
from pathlib import Path

project_root = Path().resolve().parent

sys.path.append(str(project_root / "src"))

# %%
import matplotlib.pyplot as plt
from dataset import get_dataloaders

train_loader, test_loader = get_dataloaders(
    batch_size=64,
    download=True
)

train_loader.dataset
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                RandomHorizontalFlip(p=0.5)
#                RandomCrop(size=(32, 32), padding=4)
#                ToTensor()
#                Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
#            )

# %% [markdown]
# # Experiments

# %%
from main import main
results = main()
# Out:
# Using device: cuda
#
# ==============================
# Running experiment: baseline
# ==============================
# c:\Users\joaki\mlops25\github\MLramverk\ML_ramverk_labb1\.venv\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Epoch 01/10 | train_loss=1.5795 | train_acc=0.422 | test_acc=0.568
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 from main import main
# ----> 2 results = main()
#
# File ~\mlops25\github\MLramverk\ML_ramverk_labb1\src\main.py:35, in main()
#      32 model.to(device)
#      34 # 5. Train
# ---> 35 final_acc = train(
#      36     model=model,
#      37     train_loader=train_loader,
#      38     test_loader=test_loader,
#      39     device=device,
#      40     epochs=exp["epochs"],
#      41     lr=exp["lr"],
#      42 )
#      44 # 6. Save result
#      45 results.append(
#      46     {
#      47         "name": exp["name"],
#      48         "acc": final_acc,
#      49     }
#      50 )
#
# File ~\mlops25\github\MLramverk\ML_ramverk_labb1\src\train.py:59, in train(model, train_loader, test_loader, device, epochs, lr)
#      56 correct = 0
#      57 total = 0
# ---> 59 for images, labels in train_loader:
#      60     images = images.to(device, non_blocking=True)
#      61     labels = labels.to(device, non_blocking=True)
#
# File c:\Users\joaki\mlops25\github\MLramverk\ML_ramverk_labb1\.venv\Lib\site-packages\torch\utils\data\dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File c:\Users\joaki\mlops25\github\MLramverk\ML_ramverk_labb1\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1524, in _MultiProcessingDataLoaderIter._next_data(self)
#    1520 if self._shutdown or self._tasks_outstanding <= 0:
#    1521     raise AssertionError(
#    1522         "Invalid iterator state: shutdown or no outstanding tasks when fetching next data"
#    1523     )
# -> 1524 idx, data = self._get_data()
#    1525 self._tasks_outstanding -= 1
#    1526 if self._dataset_kind == _DatasetKind.Iterable:
#    1527     # Check for _IterableDatasetStopIteration
#
# File c:\Users\joaki\mlops25\github\MLramverk\ML_ramverk_labb1\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1473, in _MultiProcessingDataLoaderIter._get_data(self)
#    1471 elif self._pin_memory:
#    1472     while self._pin_memory_thread.is_alive():
# -> 1473         success, data = self._try_get_data()
#    1474         if success:
#    1475             return data
#
# File c:\Users\joaki\mlops25\github\MLramverk\ML_ramverk_labb1\.venv\Lib\site-packages\torch\utils\data\dataloader.py:1310, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1297 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1298     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1299     # This can also be used as inner loop of fetching without timeout, with
#    (...)   1307     # Returns a 2-tuple:
#    1308     #   (bool: whether successfully get data, any: data if successful else None)
#    1309     try:
# -> 1310         data = self._data_queue.get(timeout=timeout)
#    1311         return (True, data)
#    1312     except Exception as e:
#    1313         # At timeout and error, we manually check whether any worker has
#    1314         # failed. Note that this is the only mechanism for Windows to detect
#    1315         # worker failures.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\queue.py:210, in Queue.get(self, block, timeout)
#     208 if remaining <= 0.0:
#     209     raise Empty
# --> 210 self.not_empty.wait(remaining)
#     211 if self.is_shutdown and not self._qsize():
#     212     raise ShutDown
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\threading.py:363, in Condition.wait(self, timeout)
#     361 else:
#     362     if timeout > 0:
# --> 363         gotit = waiter.acquire(True, timeout)
#     364     else:
#     365         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame(results)
display(df.style.highlight_max(subset=["acc"]))

plt.figure()
plt.bar(df["name"], df["acc"])
plt.ylim(0.7, 0.85)
plt.ylabel("Accuracy")
plt.title("Experiment Results")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 4 df = pd.DataFrame(results)
#       5 display(df.style.highlight_max(subset=["acc"]))
#       7 plt.figure()
#
# NameError: name 'results' is not defined
